# %% [markdown]
# <a href="https://colab.research.google.com/github/ChauHPham/AITextDetector/blob/main/AITextDetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install -q gradio huggingface_hub transformers torch pandas

# %cd AITextDetector
# !git pull origin main

from google.colab import userdata
import os

# Get token from Colab secrets and set as env var
try:
    os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')
    print("✅ HF_TOKEN set from Colab secrets!")
except:
    print("⚠️ HF_TOKEN secret not found in Colab")

# Now use it
from huggingface_hub import login
login()  # Will automatically use HF_TOKEN from environment


# Deploy!
# !gradio deploy
# Out:
# /content/AITextDetector
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 36 (delta 15), reused 28 (delta 10), pack-reused 0 (from 0)
# Unpacking objects: 100% (36/36), 24.20 KiB | 1.73 MiB/s, done.
# From https://github.com/ChauHPham/AITextDetector
#  * branch            main       -> FETCH_HEAD
#    87311df..ab7a73a  main       -> origin/main
# Updating ece96c8..ab7a73a
# error: Your local changes to the following files would be overwritten by merge:
# 	README.md
# Please commit your changes or stash them before you merge.
# Aborting
# ✅ HF_TOKEN set from Colab secrets!
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Need 'write' access token to create a Spaces repo.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Space available at https://huggingface.co/spaces/ChauHPham/AITextDetector
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
